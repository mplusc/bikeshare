# %%
#Importing Libraries
import pandas as pd
import numpy as np
import csv

# %%
#Assigning data files to pandas dataframe
Jan = pd.read_csv('static/data/201801_capitalbikeshare_tripdata.csv')
Jul = pd.read_csv('static/data/201807-capitalbikeshare-tripdata.csv')

# %%
#Preview dataset of January Washington DC Capital Bikeshare
Jan.head(5)
# Out:
#    Duration           Start date             End date  Start station number  \
# 0       552  2018-01-01 00:05:06  2018-01-01 00:14:18                 31104
# 1      1282  2018-01-01 00:14:30  2018-01-01 00:35:53                 31321
# 2      1265  2018-01-01 00:14:53  2018-01-01 00:35:58                 31321
# 3       578  2018-01-01 00:15:31  2018-01-01 00:25:09                 31406
# 4       372  2018-01-01 00:18:02  2018-01-01 00:24:15                 31618
#
#                    Start station  End station number  \
# 0    Adams Mill & Columbia Rd NW               31400
# 1  15th St & Constitution Ave NW               31321
# 2  15th St & Constitution Ave NW               31321
# 3            14th & Upshur St NW               31103
# 4       4th & East Capitol St NE               31619
#
#                                  End station Bike number Member type
# 0             Georgia & New Hampshire Ave NW      W00886      Member
# ...

# %%
#Preview dataset of July Washington DC Capital Bikeshare
Jul.head(5)
# Out:
#    Duration           Start date             End date  Start station number  \
# 0       267  2018-07-01 00:00:58  2018-07-01 00:05:26                 31608
# 1       530  2018-07-01 00:01:00  2018-07-01 00:09:50                 31230
# 2      3223  2018-07-01 00:01:07  2018-07-01 00:54:50                 31620
# 3      2153  2018-07-01 00:01:13  2018-07-01 00:37:06                 31258
# 4      3214  2018-07-01 00:01:13  2018-07-01 00:54:47                 31620
#
#                     Start station  End station number  \
# 0  8th & Eye St SE / Barracks Row               31610
# 1   Metro Center / 12th & G St NW               31266
# 2                   5th & F St NW               31289
# 3                Lincoln Memorial               31208
# 4                   5th & F St NW               31289
#
#                                     End station Bike number Member type
# 0  Eastern Market / 7th & North Carolina Ave SE      W23296      Member
# ...

# %%
#Converting the duration to minutes
Jan['Duration'] = Jan['Duration']/60
Jul['Duration'] = Jul['Duration']/60

# %%
Jan.head(1)
# Out:
#    Duration           Start date             End date  Start station number  \
# 0       9.2  2018-01-01 00:05:06  2018-01-01 00:14:18                 31104
#
#                  Start station  End station number  \
# 0  Adams Mill & Columbia Rd NW               31400
#
#                       End station Bike number Member type
# 0  Georgia & New Hampshire Ave NW      W00886      Member

# %%
#Formatting start date
Jan['Start date'] = pd.to_datetime(Jan['Start date'])
Jul['Start date'] = pd.to_datetime(Jul['Start date'])

# %%
Jan.head(1)
# Out:
#    Duration          Start date             End date  Start station number  \
# 0       9.2 2018-01-01 00:05:06  2018-01-01 00:14:18                 31104
#
#                  Start station  End station number  \
# 0  Adams Mill & Columbia Rd NW               31400
#
#                       End station Bike number Member type
# 0  Georgia & New Hampshire Ave NW      W00886      Member

# %%
#Adding the Days of the week and time to the data frame
Jan['Day'] = Jan['Start date'].dt.weekday_name
Jan['Time'] = Jan['Start date'].dt.time

# %%
Jan.head(2)
# Out:
#     Duration          Start date             End date  Start station number  \
# 0   9.200000 2018-01-01 00:05:06  2018-01-01 00:14:18                 31104
# 1  21.366667 2018-01-01 00:14:30  2018-01-01 00:35:53                 31321
#
#                    Start station  End station number  \
# 0    Adams Mill & Columbia Rd NW               31400
# 1  15th St & Constitution Ave NW               31321
#
#                       End station Bike number Member type     Day      Time
# 0  Georgia & New Hampshire Ave NW      W00886      Member  Monday  00:05:06
# 1   15th St & Constitution Ave NW      W01435      Casual  Monday  00:14:30

# %%
#Dropping unecessary columns
Jan
# Out:
#          Duration          Start date             End date  \
# 0        9.200000 2018-01-01 00:05:06  2018-01-01 00:14:18
# 1       21.366667 2018-01-01 00:14:30  2018-01-01 00:35:53
# 2       21.083333 2018-01-01 00:14:53  2018-01-01 00:35:58
# 3        9.633333 2018-01-01 00:15:31  2018-01-01 00:25:09
# 4        6.200000 2018-01-01 00:18:02  2018-01-01 00:24:15
# 5        6.150000 2018-01-01 00:18:07  2018-01-01 00:24:17
# 6        8.100000 2018-01-01 00:19:07  2018-01-01 00:27:14
# 7       26.916667 2018-01-01 00:21:55  2018-01-01 00:48:50
# 8       26.633333 2018-01-01 00:22:02  2018-01-01 00:48:41
# 9        8.050000 2018-01-01 00:22:10  2018-01-01 00:30:14
# 10       4.883333 2018-01-01 00:23:41  2018-01-01 00:28:35
# 11      16.900000 2018-01-01 00:25:19  2018-01-01 00:42:14
# 12       9.516667 2018-01-01 00:26:05  2018-01-01 00:35:37
# 13      21.350000 2018-01-01 00:27:25  2018-01-01 00:48:46
# 14       5.783333 2018-01-01 00:28:37  2018-01-01 00:34:25
# ...
